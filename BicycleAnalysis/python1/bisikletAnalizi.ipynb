# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sales = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/python1/sales_data.csv", parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day    Month  Year  Musteri_Yasi             Yas_Grubu  \
# 0 2011-01-01    1  January  2011            23           Youth (<25)
# 1 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 2 2011-01-01    1  January  2011            17           Youth (<25)
# 3 2011-01-01    1  January  2011            42        Adults (35-64)
# 4 2011-01-01    1  January  2011            39        Adults (35-64)
#
#   Musteri_Cinsiyeti           Ulke            Eyalet Urun_Kategorisi  \
# 0                 M      Australia          Victoria           Bikes
# 1                 F         France           Yveline           Bikes
# 2                 M         Canada  British Columbia           Bikes
# 3                 M  United States        California           Bikes
# 4                 M  United States        Washington           Bikes
#
#      Alt_Kategori                    Urun  Siparis_Miktari  Birim_Maliyeti  \
# 0  Mountain Bikes  Mountain-200 Black, 46              1.0             NaN
# 1      Road Bikes        Road-150 Red, 48              2.0          2171.0
# 2      Road Bikes        Road-250 Red, 44              1.0          1519.0
# 3      Road Bikes      Road-750 Black, 44              1.0           344.0
# 4      Road Bikes   Road-550-W Yellow, 38              3.0           713.0
#
#    Birim_Fiyati  Kazanc  Maliyet  Hasilat
# 0        2295.0   561.0   1252.0   1813.0
# 1        3578.0  1097.0   4342.0   5439.0
# 2        2443.0   900.0   1519.0   2419.0
# 3         540.0   185.0    344.0    529.0
# 4        1120.0   482.0   2139.0   2621.0

# %%
sales['Musteri_Yasi'].mean()
# Out:
# 35.91921157861212

# %%
sales['Musteri_Yasi'].plot(kind='kde', figsize=(14,4))

# %%
sales['Musteri_Yasi'].plot(kind='box', vert=False, figsize=(14,4))
# Out:
# <Axes: >

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date               113036 non-null  datetime64[ns]
#  1   Day                113036 non-null  int64
#  2   Month              113036 non-null  object
#  3   Year               113036 non-null  int64
#  4   Musteri_Yasi       113036 non-null  int64
#  5   Yas_Grubu          113036 non-null  object
#  6   Musteri_Cinsiyeti  113036 non-null  object
#  7   Ulke               113036 non-null  object
#  8   Eyalet             113036 non-null  object
#  9   Urun_Kategorisi    113036 non-null  object
#  10  Alt_Kategori       113036 non-null  object
#  11  Urun               113036 non-null  object
#  12  Siparis_Miktari    111943 non-null  float64
#  13  Birim_Maliyeti     112170 non-null  float64
#  14  Birim_Fiyati       111934 non-null  float64
#  15  Kazanc             112301 non-null  float64
#  16  Maliyet            112002 non-null  float64
#  17  Hasilat            112309 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(8)
# memory usage: 15.5+ MB

# %%
sales.isnull().sum()
# Out:
# Date                    0
# Day                     0
# Month                   0
# Year                    0
# Musteri_Yasi            0
# Yas_Grubu               0
# Musteri_Cinsiyeti       0
# Ulke                    0
# Eyalet                  0
# Urun_Kategorisi         0
# Alt_Kategori            0
# Urun                    0
# Siparis_Miktari      1093
# Birim_Maliyeti        866
# Birim_Fiyati         1102
# Kazanc                735
# Maliyet              1034
# Hasilat               727
# dtype: int64

# %%
print(f"Toplam null (boş) veri: {sales.isnull().sum().sum()}")
# Out:
# Toplam null (boş) veri: 5557

# %%
sales = sales.dropna()
sales.isnull().sum()
# Out:
# Date                 0
# Day                  0
# Month                0
# Year                 0
# Musteri_Yasi         0
# Yas_Grubu            0
# Musteri_Cinsiyeti    0
# Ulke                 0
# Eyalet               0
# Urun_Kategorisi      0
# Alt_Kategori         0
# Urun                 0
# Siparis_Miktari      0
# Birim_Maliyeti       0
# Birim_Fiyati         0
# Kazanc               0
# Maliyet              0
# Hasilat              0
# dtype: int64

# %%
sales.describe()
# Out:
#                                 Date            Day           Year  \
# count                         107610  107610.000000  107610.000000
# mean   2014-11-23 17:44:03.345414144      15.663396    2014.402463
# min              2011-01-01 00:00:00       1.000000    2011.000000
# 25%              2013-12-23 00:00:00       8.000000    2013.000000
# 50%              2014-06-27 00:00:00      16.000000    2014.000000
# 75%              2016-01-10 00:00:00      23.000000    2016.000000
# max              2016-07-31 00:00:00      31.000000    2016.000000
# std                              NaN       8.782093       1.272749
#
#         Musteri_Yasi  Siparis_Miktari  Birim_Maliyeti   Birim_Fiyati  \
# count  107610.000000    107610.000000   107610.000000  107610.000000
# mean       35.923632        11.901821      267.279686     452.853387
# min        17.000000         1.000000        1.000000       2.000000
# 25%        28.000000         2.000000        2.000000       5.000000
# 50%        35.000000        10.000000        9.000000      24.000000
# 75%        43.000000        20.000000       42.000000      70.000000
# max        87.000000        32.000000     2171.000000    3578.000000
# std        11.026944         9.559438      549.961560     922.105354
#
#               Kazanc        Maliyet        Hasilat
# count  107610.000000  107610.000000  107610.000000
# mean      285.050581     469.296627     754.347208
# min       -30.000000       1.000000       2.000000
# 25%        29.000000      28.000000      63.000000
# 50%       101.000000     108.000000     222.000000
# 75%       358.000000     420.000000     799.000000
# max     14055.000000   40014.000000   54069.000000
# std       451.964295     877.650840    1300.039894

# %%
sales['Siparis_Miktari'].mean()
# Out:
# 11.901821392063935

# %%
sales['Siparis_Miktari'].plot(kind='hist', bins=30, figsize=(14,4), ylabel="Frekans", xlabel="Siparis Miktari")
# Out:
# <Axes: xlabel='Siparis Miktari', ylabel='Frekans'>

# %%
sales['Siparis_Miktari'].plot(kind='box', vert=False, figsize=(14,4))
# Out:
# <Axes: >

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2016    28016
# 2014    27983
# 2015    23271
# 2013    23240
# 2011     2554
# 2012     2546
# Name: count, dtype: int64

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6), ylabel="Yillik Satis Miktari")
# Out:
# <Axes: ylabel='Yillik Satis Miktari'>

# %%
sales['Month'].value_counts()
# Out:
# Month
# June         10696
# December     10680
# May          10583
# April         9702
# March         9220
# January       8847
# February      8599
# November      8328
# October       8312
# August        7775
# September     7762
# July          7106
# Name: count, dtype: int64

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Month'>

# %%
sales['Ulke'].value_counts().head(1)
# Out:
# Ulke
# United States    37404
# Name: count, dtype: int64

# %%
sales['Ulke'].value_counts()
# Out:
# Ulke
# United States     37404
# Australia         22754
# Canada            13486
# United Kingdom    12933
# Germany           10532
# France            10501
# Name: count, dtype: int64

# %%
sales['Ulke'].value_counts().plot(kind='bar', figsize=(14,4))
# Out:
# <Axes: xlabel='Ulke'>

# %%
sales['Urun'].unique()
# Out:
# array(['Road-150 Red, 48', 'Road-250 Red, 44', 'Road-750 Black, 44',
#        'Road-550-W Yellow, 38', 'Road-250 Red, 58',
#        'Road-550-W Yellow, 48', 'Road-550-W Yellow, 40',
#        'Mountain-200 Silver, 42', 'Mountain-200 Black, 38',
#        'Road-750 Black, 48', 'Road-550-W Yellow, 44', 'Road-150 Red, 52',
#        'Road-650 Red, 62', 'Road-650 Red, 48', 'Road-350-W Yellow, 48',
#        'Road-650 Black, 60', 'Mountain-500 Black, 44', 'Road-150 Red, 62',
#        'Road-350-W Yellow, 42', 'Road-350-W Yellow, 40',
#        'Road-750 Black, 52', 'Mountain-200 Black, 46',
#        'Mountain-200 Black, 42', 'Road-350-W Yellow, 44',
#        'Road-650 Black, 48', 'Road-250 Black, 52',
#        'Mountain-200 Silver, 38', 'Mountain-400-W Silver, 42',
#        'Mountain-500 Black, 40', 'Road-250 Black, 58',
#        'Road-250 Black, 44', 'Mountain-100 Silver, 44',
#        'Road-250 Black, 48', 'Road-750 Black, 58',
#        'Road-550-W Yellow, 42', 'Mountain-100 Black, 48',
#        'Mountain-200 Silver, 46', 'Road-650 Black, 44',
#        'Road-150 Red, 56', 'Mountain-100 Silver, 38',
#        'Mountain-400-W Silver, 46', 'Road-650 Black, 58',
#        'Mountain-400-W Silver, 38', 'Road-650 Red, 58',
#        'Road-250 Red, 48', 'Road-150 Red, 44', 'Mountain-100 Black, 44',
#        'Road-250 Red, 52', 'Road-650 Black, 62', 'Mountain-100 Black, 38',
#        'Mountain-500 Black, 48', 'Mountain-100 Silver, 42',
#        'Road-650 Red, 44', 'Mountain-400-W Silver, 40',
#        'Mountain-500 Silver, 40', 'Mountain-500 Silver, 42',
#        'Road-650 Red, 52', 'Mountain-100 Black, 42', 'Road-650 Red, 60',
#        'Mountain-500 Black, 42', 'Mountain-500 Silver, 52',
#        'Mountain-500 Silver, 44', 'Mountain-500 Silver, 48',
#        'Road-650 Black, 52', 'Mountain-500 Black, 52',
#        'Mountain-100 Silver, 48', 'All-Purpose Bike Stand',
#        'Road Bottle Cage', 'Water Bottle - 30 oz.',
#        'Sport-100 Helmet, Blue', 'Sport-100 Helmet, Black',
#        'Sport-100 Helmet, Red', 'Long-Sleeve Logo Jersey, XL',
#        'Long-Sleeve Logo Jersey, M', 'Short-Sleeve Classic Jersey, L',
#        'Patch Kit/8 Patches', 'ML Road Tire', 'LL Road Tire',
#        'Road Tire Tube', 'Touring-2000 Blue, 60',
#        'Touring-1000 Yellow, 60', 'Touring-1000 Blue, 54',
#        'Mountain Bottle Cage', 'AWC Logo Cap', 'Fender Set - Mountain',
#        'Half-Finger Gloves, S', 'Short-Sleeve Classic Jersey, M',
#        'LL Mountain Tire', 'Mountain Tire Tube', 'Touring-2000 Blue, 46',
#        'Half-Finger Gloves, L', 'Racing Socks, L', 'Racing Socks, M',
#        'Touring Tire Tube', 'Touring-2000 Blue, 50',
#        'Touring-1000 Yellow, 54', 'Touring-1000 Blue, 46',
#        'Hydration Pack - 70 oz.', 'HL Road Tire', 'HL Mountain Tire',
#        'Touring-1000 Yellow, 50', 'Classic Vest, S',
#        'Bike Wash - Dissolver', 'Touring-1000 Blue, 60',
#        'Touring-3000 Blue, 54', 'Long-Sleeve Logo Jersey, L',
#        'Classic Vest, M', 'Long-Sleeve Logo Jersey, S',
#        'Short-Sleeve Classic Jersey, XL', 'Classic Vest, L',
#        'Touring-3000 Blue, 50', 'Touring-1000 Yellow, 46',
#        'Short-Sleeve Classic Jersey, S', 'Touring-3000 Yellow, 58',
#        'Touring-3000 Yellow, 62', 'Touring Tire', 'Hitch Rack - 4-Bike',
#        'Half-Finger Gloves, M', "Women's Mountain Shorts, L",
#        'Touring-3000 Blue, 44', 'Touring-1000 Blue, 50',
#        'Touring-3000 Yellow, 54', 'Touring-3000 Yellow, 50',
#        'Touring-3000 Blue, 62', 'ML Mountain Tire',
#        'Touring-3000 Blue, 58', "Women's Mountain Shorts, M",
#        'Touring-3000 Yellow, 44', "Women's Mountain Shorts, S",
#        'Touring-2000 Blue, 54'], dtype=object)

# %%
sales['Urun'].value_counts().head(10).plot(kind='bar', figsize=(14,4))
# Out:
# <Axes: xlabel='Urun'>

# %%
sales['Yas_Grubu'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
sales.plot(kind='scatter', x='Birim_Maliyeti', y='Birim_Fiyati', figsize=(6,6))
# Out:
# <Axes: xlabel='Birim_Maliyeti', ylabel='Birim_Fiyati'>

# %%
sales.plot(kind='scatter', x='Siparis_Miktari', y='Kazanc', figsize=(6,6))
# Out:
# <Axes: xlabel='Siparis_Miktari', ylabel='Kazanc'>

# %%
sales.groupby('Ulke')['Kazanc'].mean().plot(kind='bar', figsize=(10,4))
# Out:
# <Axes: xlabel='Ulke'>

# %%
sales[['Kazanc', 'Ulke']].boxplot(by='Ulke', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Kazanc'}, xlabel='[Ulke]'>

# %%
sales[['Musteri_Yasi', 'Ulke']].boxplot(by='Ulke', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Musteri_Yasi'}, xlabel='[Ulke]'>

# %%
sales['Hesaplanmis_Tarih'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

sales['Hesaplanmis_Tarih'].head()
# Out:
# 1    2011-January-1
# 2    2011-January-1
# 3    2011-January-1
# 4    2011-January-1
# 5    2011-January-2
# Name: Hesaplanmis_Tarih, dtype: object

# %%
sales['Hesaplanmis_Tarih'] = pd.to_datetime(sales['Hesaplanmis_Tarih'])

sales['Hesaplanmis_Tarih'].head()
# Out:
# 1   2011-01-01
# 2   2011-01-01
# 3   2011-01-01
# 4   2011-01-01
# 5   2011-01-02
# Name: Hesaplanmis_Tarih, dtype: datetime64[ns]

# %%
sales.loc[(sales['Ulke'] == 'Canada') | (sales['Ulke'] == 'France')].shape[0]
# Out:
# 23987

# %%
sales['Musteri_Cinsiyeti'].value_counts()
# Out:
# Musteri_Cinsiyeti
# M    55570
# F    52040
# Name: count, dtype: int64

# %%
sales['Musteri_Cinsiyeti'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Musteri_Cinsiyeti'>

# %%
sales.loc[(sales['Musteri_Cinsiyeti'] == 'F') & (sales['Hasilat'] == 500)].shape[0]
# Out:
# 25

# %%
sales.sort_values(['Hasilat'], ascending=False).head(5)
# Out:
#            Date  Day     Month  Year  Musteri_Yasi             Yas_Grubu  \
# 8193 2013-07-24   24      July  2013            52        Adults (35-64)
# 1261 2011-07-08    8      July  2011            22           Youth (<25)
# 1233 2011-07-05    5      July  2011            26  Young Adults (25-34)
# 848  2011-05-12   12       May  2011            19           Youth (<25)
# 264  2011-02-11   11  February  2011            39        Adults (35-64)
#
#      Musteri_Cinsiyeti       Ulke            Eyalet Urun_Kategorisi  \
# 8193                 M  Australia        Queensland        Clothing
# 1261                 M     Canada           Alberta           Bikes
# 1233                 M     Canada  British Columbia           Bikes
# 848                  F     Canada  British Columbia           Bikes
# 264                  M     Canada  British Columbia           Bikes
#
#      Alt_Kategori                     Urun  Siparis_Miktari  Birim_Maliyeti  \
# 8193        Vests  Touring-1000 Yellow, 50             27.0          1482.0
# 1261   Road Bikes         Road-150 Red, 48              4.0          2171.0
# 1233   Road Bikes         Road-150 Red, 56              4.0          2171.0
# 848    Road Bikes         Road-150 Red, 62              4.0          2171.0
# 264    Road Bikes         Road-150 Red, 52              4.0          2171.0
#
#       Birim_Fiyati   Kazanc  Maliyet  Hasilat Hesaplanmis_Tarih
# 8193        2384.0  14055.0  40014.0  54069.0        2013-07-24
# 1261        3578.0   5628.0   8684.0  14312.0        2011-07-08
# 1233        3578.0   5485.0   8684.0  14169.0        2011-07-05
# 848         3578.0   5485.0   8684.0  14169.0        2011-05-12
# 264         3578.0   5485.0   8684.0  14169.0        2011-02-11

# %%
cond = sales['Hasilat'] == sales['Hasilat'].max()

sales.loc[cond]
# Out:
#            Date  Day Month  Year  Musteri_Yasi       Yas_Grubu  \
# 8193 2013-07-24   24  July  2013            52  Adults (35-64)
#
#      Musteri_Cinsiyeti       Ulke      Eyalet Urun_Kategorisi Alt_Kategori  \
# 8193                 M  Australia  Queensland        Clothing        Vests
#
#                          Urun  Siparis_Miktari  Birim_Maliyeti  Birim_Fiyati  \
# 8193  Touring-1000 Yellow, 50             27.0          1482.0        2384.0
#
#        Kazanc  Maliyet  Hasilat Hesaplanmis_Tarih
# 8193  14055.0  40014.0  54069.0        2013-07-24

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 4759

# %%
sales.groupby(sales['Hesaplanmis_Tarih'].dt.to_period('M'))['Siparis_Miktari'].sum().plot(kind='bar', figsize=(14, 4))
plt.xlabel('Month-Year')
plt.ylabel('Toplam Satis')
plt.title('Aylik satis')
plt.show()

# %%
corr = sales.corr(numeric_only=True)

corr
# Out:
#                       Day      Year  Musteri_Yasi  Siparis_Miktari  \
# Day              1.000000 -0.008141     -0.016302        -0.002620
# Year            -0.008141  1.000000      0.040500         0.122283
# Musteri_Yasi    -0.016302  0.040500      1.000000         0.025774
# Siparis_Miktari -0.002620  0.122283      0.025774         1.000000
# Birim_Maliyeti   0.003171 -0.217627     -0.021508        -0.515822
# Birim_Fiyati     0.003240 -0.213724     -0.020425        -0.515929
# Kazanc           0.004926 -0.182957      0.003566        -0.240524
# Maliyet          0.003598 -0.218417     -0.017073        -0.344528
# Hasilat          0.004141 -0.211058     -0.010286        -0.316208
#
#                  Birim_Maliyeti  Birim_Fiyati    Kazanc   Maliyet   Hasilat
# Day                    0.003171      0.003240  0.004926  0.003598  0.004141
# Year                  -0.217627     -0.213724 -0.182957 -0.218417 -0.211058
# Musteri_Yasi          -0.021508     -0.020425  0.003566 -0.017073 -0.010286
# Siparis_Miktari       -0.515822     -0.515929 -0.240524 -0.344528 -0.316208
# Birim_Maliyeti         1.000000      0.997896  0.744354  0.837266  0.824012
# Birim_Fiyati           0.997896      1.000000  0.753275  0.833711  0.824714
# Kazanc                 0.744354      0.753275  1.000000  0.901967  0.956568
# Maliyet                0.837266      0.833711  0.901967  1.000000  0.988668
# Hasilat                0.824012      0.824714  0.956568  0.988668  1.000000
